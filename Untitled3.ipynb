# %% [markdown]
# <a href="https://colab.research.google.com/github/ItsArnavRathi/Smart-student-feedback-insight-system/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /usr/local/lib/python3.12/dist-packages (from kagglehub) (0.1.16)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (26.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (5.29.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2026.2.25)

# %%
import kagglehub

# Download dataset
path = kagglehub.dataset_download("omarsobhy14/university-students-complaints-and-reports")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'university-students-complaints-and-reports' dataset.
# Path to dataset files: /kaggle/input/university-students-complaints-and-reports

# %%
import os

print(os.listdir(path))
# Out:
# ['Datasetprojpowerbi.csv']

# %%
import pandas as pd

file_path = path + "/Datasetprojpowerbi.csv"   # change this after checking
df = pd.read_csv(file_path)

df.head()
# Out:
#                             Genre  \
# 0  Academic Support and Resources
# 1  Academic Support and Resources
# 2  Academic Support and Resources
# 3  Academic Support and Resources
# 4  Academic Support and Resources
#
#                                              Reports  Age   Gpa  Year  Count  \
# 0  The limited access to research databases and m...   27  2.18     2      1
# 1  I'm having trouble finding the course material...   23  3.11     2      1
# 2  It's frustrating to have limited access to res...   20  3.68     2      1
# 3  I'm really struggling in one of my classes but...   20  1.30     2      1
# 4   I am really struggling with understanding the...   26  2.50     2      1
#
#   Gender Nationality
# 0      M       Egypt
# 1      F       Egypt
# 2      F       Egypt
# 3      F       Egypt
# 4      F       Egypt

# %%
import pandas as pd
df = pd.read_csv(file_path)
print(df.columns)
# Out:
# Index(['Genre', 'Reports', 'Age', 'Gpa', 'Year', 'Count', 'Gender',
#        'Nationality'],
#       dtype='object')

# %%
for col in df.columns:
    print(col)
    print(df[col].head(3))
    print("--------")
# Out:
# Genre
# 0    Academic Support and Resources
# 1    Academic Support and Resources
# 2    Academic Support and Resources
# Name: Genre, dtype: object
# --------
# Reports
# 0    The limited access to research databases and m...
# 1    I'm having trouble finding the course material...
# 2    It's frustrating to have limited access to res...
# Name: Reports, dtype: object
# --------
# Age
# 0    27
# 1    23
# 2    20
# Name: Age, dtype: int64
# --------
# Gpa
# 0    2.18
# 1    3.11
# 2    3.68
# Name: Gpa, dtype: float64
# --------
# Year
# 0    2
# 1    2
# 2    2
# Name: Year, dtype: int64
# --------
# Count
# 0    1
# 1    1
# 2    1
# Name: Count, dtype: int64
# --------
# Gender
# 0    M
# 1    F
# 2    F
# Name: Gender, dtype: object
# --------
# Nationality
# 0    Egypt
# 1    Egypt
# 2    Egypt
# Name: Nationality, dtype: object
# --------

# %%
df = df[['Reports']]

# %%
df = df.dropna()

# %%
df = df.head(100)

# %%
df.shape
df.columns
# Out:
# Index(['Reports'], dtype='object')

# %%
df.head(5)
# Out:
#                                              Reports
# 0  The limited access to research databases and m...
# 1  I'm having trouble finding the course material...
# 2  It's frustrating to have limited access to res...
# 3  I'm really struggling in one of my classes but...
# 4   I am really struggling with understanding the...

# %%
df.isnull().sum()
# Out:
# Reports    0
# dtype: int64

# %%
df['Complaint_length'] = df['Reports'].apply(len)
df['Complaint_length'].describe()
# Out:
# count    100.000000
# mean     136.180000
# std       24.988636
# min       67.000000
# 25%      118.750000
# 50%      134.000000
# 75%      153.250000
# max      198.000000
# Name: Complaint_length, dtype: float64

# %%
import re

# ---- Keep only relevant columns ----
# Adjust column name if different in your file
df = df[['Reports']].copy()

# ---- Drop nulls ----
df.dropna(subset=['Reports'], inplace=True)
df.reset_index(drop=True, inplace=True)

print(f"Total records after cleaning: {len(df)}")

# ---- Text Cleaning Function ----
def clean_text(text):
    text = str(text).lower()                        # Lowercase
    text = re.sub(r'http\S+|www\S+', '', text)      # Remove URLs
    text = re.sub(r'[^a-z\s]', '', text)            # Remove numbers & special chars
    text = re.sub(r'\s+', ' ', text).strip()        # Remove extra spaces
    return text

# ---- Apply Cleaning ----
df['Cleaned_Report'] = df['Reports'].apply(clean_text)

# ---- Limit size for Colab (to avoid memory issues) ----
df = df.sample(n=min(500, len(df)), random_state=42).reset_index(drop=True)

print(f"\nWorking with {len(df)} samples")
print("\n--- Sample cleaned text ---")
print(df[['Reports', 'Cleaned_Report']].head(3))
# Out:
# Total records after cleaning: 100
#
# Working with 100 samples
#
# --- Sample cleaned text ---
#                                              Reports  \
# 0  Limited course availability is making it impos...
# 1  Limited access to technology and software is a...
# 2  It's really frustrating to not have more acces...
#
#                                       Cleaned_Report
# 0  limited course availability is making it impos...
# 1  limited access to technology and software is a...
# 2  its really frustrating to not have more access...

# %%
from transformers import pipeline

# ---- Load pre-trained sentiment model ----
# DistilBERT: lightweight BERT, fast on Colab, strong accuracy
print("Loading sentiment model... (this may take 1-2 minutes)")

sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english",
    truncation=True,
    max_length=512
)

print("Model loaded successfully!")

# ---- Run sentiment analysis in batches ----
# Batching avoids memory crashes on Colab
def get_sentiment_batch(texts, batch_size=32):
    results = []
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size].tolist()
        batch_results = sentiment_pipeline(batch)
        results.extend(batch_results)
        print(f"  Processed {min(i+batch_size, len(texts))}/{len(texts)} rows...", end='\r')
    print("\nDone!")
    return results

# ---- Apply to cleaned text ----
print("\nRunning sentiment analysis...")
raw_results = get_sentiment_batch(df['Cleaned_Report'])

# ---- Extract label and score ----
df['Sentiment']       = [r['label'] for r in raw_results]   # POSITIVE / NEGATIVE
df['Sentiment_Score'] = [round(r['score'], 4) for r in raw_results]  # Confidence

# ---- Map to friendlier labels ----
df['Sentiment'] = df['Sentiment'].map({'POSITIVE': 'Positive', 'NEGATIVE': 'Negative'})

# ---- Preview results ----
print("\n--- Sample Sentiment Results ---")
print(df[['Cleaned_Report', 'Sentiment', 'Sentiment_Score']].head(6).to_string())

print("\n--- Sentiment Distribution ---")
print(df['Sentiment'].value_counts())
# Out:
# Loading sentiment model... (this may take 1-2 minutes)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Model loaded successfully!
#
# Running sentiment analysis...
#   Processed 100/100 rows...
# Done!
#
# --- Sample Sentiment Results ---
#                                                                                                                                                                                    Cleaned_Report Sentiment  Sentiment_Score
# 0                                                                                                  limited course availability is making it impossible to complete my degree requirements on time  Negative           0.9998
# 1                                        limited access to technology and software is a major issue its hindering our ability to complete assignments and keep up with the demands of our courses  Negative           0.9998
# 2                                                  its really frustrating to not have more access to academic advisors its important that we have support to be able to plan our academic careers  Negative           0.9969
# 3                                            im having trouble accessing research databases and materials because the library hours are limited and theyre often closed when i have time to study  Negative           0.9996
# 4                                                      its hard to do group projects when we have limited access to technology and software it puts us at a disadvantage compared to other groups  Negative           0.9994
# 5  im an international student and im having trouble accessing some of the online resources because of regional restrictions its frustrating to feel like im missing out because of where im from  Negative           0.9998
#
# --- Sentiment Distribution ---
# Sentiment
# Negative    97
# Positive     3
# Name: count, dtype: int64

# %%
from transformers import pipeline as hf_pipeline

# ---- Define complaint categories ----
CATEGORIES = [
    "Academic",
    "Library & Resources",
    "Technology & Software",
    "Faculty & Teaching",
    "Administration & Fees",
    "Campus Facilities",
    "International Students",
    "Mental Health & Support"
]

# ---- Load zero-shot classification model ----
print("Loading classification model... (may take 1-2 minutes)")

classifier = hf_pipeline(
    "zero-shot-classification",
    model="facebook/bart-large-mnli",
    device=-1  # CPU mode for Colab (use 0 for GPU if available)
)

print("Model loaded!\n")

# ---- Run classification in batches ----
def classify_batch(texts, categories, batch_size=16):
    labels = []
    scores = []
    total = len(texts)
    for i in range(0, total, batch_size):
        batch = texts[i:i+batch_size].tolist()
        for text in batch:
            result = classifier(text, candidate_labels=categories, truncation=True)
            labels.append(result['labels'][0])        # Top predicted category
            scores.append(round(result['scores'][0], 4))  # Confidence score
        print(f"  Classified {min(i+batch_size, total)}/{total} rows...", end='\r')
    print("\nDone!")
    return labels, scores

# ---- Apply to cleaned complaints ----
print("Running category classification (this takes ~3-5 mins on CPU)...")
cat_labels, cat_scores = classify_batch(df['Cleaned_Report'], CATEGORIES)

# ---- Store results ----
df['Category']       = cat_labels
df['Category_Score'] = cat_scores

# ---- Preview results ----
print("\n--- Sample Classification Results ---")
print(df[['Cleaned_Report', 'Category', 'Category_Score']].head(6).to_string())

print("\n--- Category Distribution ---")
print(df['Category'].value_counts())
# Out:
# Loading classification model... (may take 1-2 minutes)
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Model loaded!
#
# Running category classification (this takes ~3-5 mins on CPU)...
#   Classified 100/100 rows...
# Done!
#
# --- Sample Classification Results ---
#                                                                                                                                                                                    Cleaned_Report                Category  Category_Score
# 0                                                                                                  limited course availability is making it impossible to complete my degree requirements on time                Academic          0.5017
# 1                                        limited access to technology and software is a major issue its hindering our ability to complete assignments and keep up with the demands of our courses   Technology & Software          0.8445
# 2                                                  its really frustrating to not have more access to academic advisors its important that we have support to be able to plan our academic careers                Academic          0.7123
# 3                                            im having trouble accessing research databases and materials because the library hours are limited and theyre often closed when i have time to study     Library & Resources          0.4690
# 4                                                      its hard to do group projects when we have limited access to technology and software it puts us at a disadvantage compared to other groups   Technology & Software          0.6132
# 5  im an international student and im having trouble accessing some of the online resources because of regional restrictions its frustrating to feel like im missing out because of where im from  International Students          0.9690
#
# --- Category Distribution ---
# Category
# Academic                  76
# Technology & Software     13
# Library & Resources        7
# Faculty & Teaching         2
# International Students     1
# Administration & Fees      1
# Name: count, dtype: int64

# %%
print("=" * 60)
print("   SMART STUDENT FEEDBACK INSIGHT SYSTEM")
print("   Structured Analysis Report")
print("=" * 60)

total = len(df)
neg = (df['Sentiment'] == 'Negative').sum()
pos = (df['Sentiment'] == 'Positive').sum()
top_cat = df['Category'].value_counts().idxmax()
avg_conf = df['Category_Score'].mean()

print(f"\nTotal Complaints Analyzed : {total}")
print(f"Negative Sentiment        : {neg} ({neg/total*100:.1f}%)")
print(f"Positive Sentiment        : {pos} ({pos/total*100:.1f}%)")
print(f"Most Common Category      : {top_cat}")
print(f"Avg Classification Conf.  : {avg_conf:.2%}")

print("\n--- Full Structured DataFrame (first 10 rows) ---")
output_df = df[['Reports', 'Sentiment', 'Sentiment_Score', 'Category', 'Category_Score']].copy()
output_df.columns = ['Original Report', 'Sentiment', 'Sent. Confidence',
                     'Category', 'Cat. Confidence']
print(output_df.head(10).to_string())

# Save to CSV
output_df.to_csv('feedback_insights.csv', index=False)
print("\nResults saved to: feedback_insights.csv")
# Out:
# ============================================================
#    SMART STUDENT FEEDBACK INSIGHT SYSTEM
#    Structured Analysis Report
# ============================================================
#
# Total Complaints Analyzed : 100
# Negative Sentiment        : 97 (97.0%)
# Positive Sentiment        : 3 (3.0%)
# Most Common Category      : Academic
# Avg Classification Conf.  : 54.68%
#
# --- Full Structured DataFrame (first 10 rows) ---
#                                                                                                                                                                                          Original Report Sentiment  Sent. Confidence                Category  Cat. Confidence
# 0                                                                                                        Limited course availability is making it impossible to complete my degree requirements on time.  Negative            0.9998                Academic           0.5017
# 1                                            Limited access to technology and software is a major issue. It's hindering our ability to complete assignments and keep up with the demands of our courses.  Negative            0.9998   Technology & Software           0.8445
# 2                                                     It's really frustrating to not have more access to academic advisors. It's important that we have support to be able to plan our academic careers.  Negative            0.9969                Academic           0.7123
# 3                                                I'm having trouble accessing research databases and materials because the library hours are limited and they're often closed when I have time to study.  Negative            0.9996     Library & Resources           0.4690
# 4                                                          It's hard to do group projects when we have limited access to technology and software. It puts us at a disadvantage compared to other groups.  Negative            0.9994   Technology & Software           0.6132
# 5  I'm an international student and I'm having trouble accessing some of the online resources because of regional restrictions. It's frustrating to feel like I'm missing out because of where I'm from.  Negative            0.9998  International Students           0.9690
# 6                                                                                    The professor for this course is biased and it's affecting my grade. They seem to have favorites and it's not fair.  Negative            0.9994                Academic           0.5677
# 7                                                             The lack of access to academic advisors is really concerning, especially when I have questions about course selection and career planning.  Negative            0.9812                Academic           0.6244
# 8                          There have been several honor code violations in this course and it's really disappointing. I thought this was a place of higher learning and respect for academic integrity.  Negative            0.9993                Academic           0.7951
# 9                                       The limited access to research databases and materials is causing a lot of frustration among students. We need better access to be able to succeed academically.  Negative            0.9994                Academic           0.6499
#
# Results saved to: feedback_insights.csv

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

# ---- Global Style ----
plt.rcParams.update({
    'font.family': 'DejaVu Sans',
    'font.size': 11,
    'axes.titlesize': 13,
    'axes.titleweight': 'bold',
    'figure.facecolor': '#F8F9FA'
})
COLORS_SENT = {'Negative': '#E74C3C', 'Positive': '#2ECC71'}
PALETTE     = ['#3498DB','#E74C3C','#2ECC71','#F39C12','#9B59B6','#1ABC9C','#E67E22','#E91E63']

# ======================
# CHART 1: Sentiment Pie
# ======================
fig, ax = plt.subplots(figsize=(6, 5), facecolor='#F8F9FA')
sent_counts = df['Sentiment'].value_counts()
wedges, texts, autotexts = ax.pie(
    sent_counts,
    labels=sent_counts.index,
    autopct='%1.1f%%',
    colors=[COLORS_SENT[s] for s in sent_counts.index],
    startangle=140,
    explode=[0.05] * len(sent_counts),
    textprops={'fontsize': 12}
)
for at in autotexts:
    at.set_fontweight('bold')
ax.set_title('Sentiment Distribution of Student Complaints', pad=15)
plt.tight_layout()
plt.savefig('chart1_sentiment_pie.png', dpi=150, bbox_inches='tight')
plt.show()
print("Chart 1 saved")

# ==========================
# CHART 2: Category Bar Chart
# ==========================
fig, ax = plt.subplots(figsize=(9, 5), facecolor='#F8F9FA')
cat_counts = df['Category'].value_counts()
bars = ax.barh(cat_counts.index, cat_counts.values,
               color=PALETTE[:len(cat_counts)], edgecolor='white', height=0.6)
for bar, val in zip(bars, cat_counts.values):
    ax.text(val + 0.3, bar.get_y() + bar.get_height()/2,
            str(val), va='center', fontweight='bold', fontsize=11)
ax.set_xlabel('Number of Complaints')
ax.set_title('Complaint Category Distribution')
ax.set_facecolor('#F0F3F4')
ax.invert_yaxis()
plt.tight_layout()
plt.savefig('chart2_category_bar.png', dpi=150, bbox_inches='tight')
plt.show()
print("Chart 2 saved")

# ===================================
# CHART 3: Sentiment per Category
# ===================================
fig, ax = plt.subplots(figsize=(10, 5), facecolor='#F8F9FA')
cross = pd.crosstab(df['Category'], df['Sentiment'])
cross.plot(kind='bar', ax=ax,
           color=[COLORS_SENT.get(c, '#AAB7B8') for c in cross.columns],
           edgecolor='white', width=0.7)
ax.set_title('Sentiment Breakdown per Category')
ax.set_xlabel('Category')
ax.set_ylabel('Count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=35, ha='right')
ax.legend(title='Sentiment')
ax.set_facecolor('#F0F3F4')
plt.tight_layout()
plt.savefig('chart3_sentiment_per_category.png', dpi=150, bbox_inches='tight')
plt.show()
print("Chart 3 saved")

# =====================================
# CHART 4: Confidence Score Distribution
# =====================================
fig, axes = plt.subplots(1, 2, figsize=(11, 4), facecolor='#F8F9FA')
for ax, col, color, title in zip(
    axes,
    ['Sentiment_Score', 'Category_Score'],
    ['#3498DB', '#E67E22'],
    ['Sentiment Model Confidence', 'Classification Model Confidence']
):
    ax.hist(df[col], bins=15, color=color, edgecolor='white', alpha=0.85)
    ax.axvline(df[col].mean(), color='black', linestyle='--', linewidth=1.5,
               label=f'Mean: {df[col].mean():.2f}')
    ax.set_title(title)
    ax.set_xlabel('Confidence Score')
    ax.set_ylabel('Number of Complaints')
    ax.legend()
    ax.set_facecolor('#F0F3F4')
fig.suptitle('Model Confidence Score Distributions', fontweight='bold', fontsize=13)
plt.tight_layout()
plt.savefig('chart4_confidence_dist.png', dpi=150, bbox_inches='tight')
plt.show()
print("Chart 4 saved")

# =====================================
# CHART 5: Heatmap — Category vs Sentiment
# =====================================
fig, ax = plt.subplots(figsize=(8, 5), facecolor='#F8F9FA')
heatmap_data = pd.crosstab(df['Category'], df['Sentiment'])
sns.heatmap(heatmap_data, annot=True, fmt='d', cmap='RdYlGn',
            linewidths=0.5, linecolor='white',
            ax=ax, cbar_kws={'label': 'Count'})
ax.set_title('Heatmap: Category vs Sentiment')
ax.set_xlabel('Sentiment')
ax.set_ylabel('Category')
plt.tight_layout()
plt.savefig('chart5_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()
print("Chart 5 saved")

print("\nAll 5 charts generated and saved!")
# Out:
# Chart 1 saved
# Chart 2 saved
# Chart 3 saved
# Chart 4 saved
# Chart 5 saved
#
# All 5 charts generated and saved!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import numpy as np

# ---- Group complaints by category ----
category_texts = df.groupby('Category')['Cleaned_Report'].apply(lambda x: ' '.join(x))

# ---- Fit TF-IDF on all categories ----
vectorizer = TfidfVectorizer(
    max_features=500,
    stop_words='english',
    ngram_range=(1, 2)      # single words AND two-word phrases
)
tfidf_matrix = vectorizer.fit_transform(category_texts)
feature_names = vectorizer.get_feature_names_out()

# ---- Extract top N keywords per category ----
TOP_N = 6

print("=" * 60)
print("  TOP KEYWORDS PER COMPLAINT CATEGORY")
print("=" * 60)

category_keywords = {}
for i, category in enumerate(category_texts.index):
    scores = tfidf_matrix[i].toarray()[0]
    top_indices = scores.argsort()[::-1][:TOP_N]
    top_keywords = [(feature_names[j], round(scores[j], 4)) for j in top_indices if scores[j] > 0]
    category_keywords[category] = top_keywords

    print(f"\n{category}")
    for kw, score in top_keywords:
        bar = '█' * int(score * 40)
        print(f"   {kw:<30} {bar} ({score})")

print("\n")
# Out:
# ============================================================
#   TOP KEYWORDS PER COMPLAINT CATEGORY
# ============================================================
#
# Academic
#    academic                       ██████████████ (0.3656)
#    course                         ███████████ (0.2958)
#    access                         ██████████ (0.2531)
#    limited                        █████████ (0.2454)
#    materials                      ████████ (0.2089)
#    im                             ██████ (0.1577)
#
# Administration & Fees
#    getting                        ████████████████████ (0.5171)
#    getting moneys                 ████████████ (0.3153)
#    fees high                      ████████████ (0.3153)
#    worth                          ████████████ (0.3153)
#    getting getting                ████████████ (0.3153)
#    high getting                   ████████████ (0.3153)
#
# Faculty & Teaching
#    doesnt care                    ███████████████ (0.3777)
#    care                           ███████████████ (0.3777)
#    professor                      ████████████ (0.3098)
#    professor doesnt               ████████████ (0.3098)
#    doesnt                         ██████████ (0.2615)
#    course                         ████████ (0.2241)
#
# International Students
#    im                             ██████████████████████████ (0.6723)
#    im international               ███████████ (0.2833)
#    student                        ███████ (0.1961)
#    frustrating feel               ███████ (0.1961)
#    trouble accessing              ███████ (0.1961)
#    online                         ███████ (0.1961)
#
# Library & Resources
#    research                       ████████████████ (0.4237)
#    materials                      ██████████████ (0.3707)
#    databases                      ██████████ (0.2648)
#    research databases             ██████████ (0.2648)
#    databases materials            ██████████ (0.2648)
#    library                        ██████████ (0.2583)
#
# Technology & Software
#    technology software            ███████████████ (0.3989)
#    technology                     ███████████████ (0.3989)
#    access technology              ██████████████ (0.3682)
#    software                       █████████████ (0.3271)
#    access                         ███████████ (0.2762)
#    limited                        ██████████ (0.2549)

# %%
# ---- Visualize top keywords per category ----
categories_to_plot = [c for c in category_keywords if len(category_keywords[c]) >= 3]
n_cats = len(categories_to_plot)

PALETTE = ['#3498DB','#E74C3C','#2ECC71','#F39C12','#9B59B6','#1ABC9C']

fig, axes = plt.subplots(
    nrows=(n_cats + 1) // 2,
    ncols=2,
    figsize=(14, 4 * ((n_cats + 1) // 2)),
    facecolor='#F8F9FA'
)
axes = axes.flatten()

for idx, category in enumerate(categories_to_plot):
    ax = axes[idx]
    keywords = category_keywords[category]
    words  = [kw[0] for kw in keywords]
    scores = [kw[1] for kw in keywords]
    color  = PALETTE[idx % len(PALETTE)]

    bars = ax.barh(words[::-1], scores[::-1], color=color, edgecolor='white', height=0.55)
    for bar, score in zip(bars, scores[::-1]):
        ax.text(bar.get_width() + 0.002, bar.get_y() + bar.get_height()/2,
                f'{score:.3f}', va='center', fontsize=9, fontweight='bold')

    ax.set_title(f'📌 {category}', fontweight='bold', fontsize=11, color=color)
    ax.set_xlabel('TF-IDF Score')
    ax.set_facecolor('#F0F3F4')
    ax.spines[['top','right']].set_visible(False)
    ax.set_xlim(0, max(scores) * 1.3)

# Hide any unused subplots
for j in range(idx + 1, len(axes)):
    axes[j].set_visible(False)

fig.suptitle('Top Keywords per Complaint Category (TF-IDF)',
             fontsize=14, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig('chart6_keywords_tfidf.png', dpi=150, bbox_inches='tight')
plt.show()
print("Chart 6 saved!")
# Out:
# /tmp/ipykernel_7995/536201720.py:39: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_7995/536201720.py:40: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   plt.savefig('chart6_keywords_tfidf.png', dpi=150, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# Chart 6 saved!
